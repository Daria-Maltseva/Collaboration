# %% [markdown]
# # 2. Предобработка данных и получение идентифицирующих признаков

# %% [markdown]
# ## Часть 1. Предобработка данных

# %% [markdown]
# На данном этапе перед нами стоит задача предобработать данные, выгруженные через API Elibrary ранее (см. файл в репозитории `1. Выгрузка данных по статьям`).
#
# **Перед нами стоит несколько задач:**
# 1. Предобработать данные по русскоязычным фамилиям и инициалам;
# 2. Предобработать данные по англоязычным фамилиям и инициалам;
# 3. Предобработать данные по русско- и англоязычным аффилиациям;
# 4. Провести процедуру присвоения собственных id авторов;
#
# В этой части (`Часть 1`) – нами проводятся первые две процедуры - предобработка данных по русско- и англоязычным фамилиям и инициалам.
#
#
# Почему такая необходимость возникла? Дело в том, что изначально мы обнаружили, что в данных достаточно много авторов без id во внутренней системе Elibrary. Этот факт осложняет дальнейшую работу с данными и их анализ – мы не сможем построить сети на основании id авторов, если они не достаточно корректные. Поэтому нами было принято решение подготовить собственные id авторов, основываясь на ФИО и данных об аффилиациях авторов.
#
#
# Однако, и на этом этапе возникла проблема – Elibrary не контролирует единообразность записи фамилий, имен и инициалов; туда можно вписать разные знаки препинания; иногда в фамилии вписываются сразу и фамилиии, и инициалы, и так далее.
#
# В этом ноутбуке демонстрируются разные проблемы и способы их решения.
#
# **Получаемые в результате первой чаасти предобработки файлы:**
# 1. `problem1.xlsx` - строчки с информацией о статьях, для которых отсутствует информация даже о первом(!) авторе (то есть, нет информации об авторах вообще). Необходимо заполнение вручную;
# 2. `problem2.xlsx` - строчки с информацией о статьях, в фамилиях и инициалах авторов которых встречаются вопросительные знаки. Необходимо заполнение вручную;
# 3. `problem3.xlsx` - строчки с информацией о статьях, среди авторов которых встречаются авторы с не-русскими фамилиями если в разделе с инициалами у них не указаны иниициалы (то есть, в ячейку с фамилией отнесена и фамилия, и инициалы). Необходимо заполнение вручную.

# %%
import pandas as pd # импортируем библиотеку для работы с таблицами
df = pd.read_excel('data.xlsx') # в этом файле находится выгруженная предварительно информация о статьях авторов 
df.drop(axis=1, columns=['Unnamed: 0.1', 'Unnamed: 0', 'Column1'], inplace=True)
df
# Out:
#              id  genreId  author_1_id author_1_affiliation_id
# 0      15485609        4          0.0    [['7113'], ['7113']]  \
# 1      15488335        4     675896.0        ['none', 'none']
# 2      15488853        4     820606.0       [['340'], 'none']
# 3      15500786        4      77952.0       [['210'], 'none']
# 4      15501422        4     746025.0      [['2541'], 'none']
# ...         ...      ...          ...                     ...
# 75227  48109813        4     725411.0       ['none', ['211']]
# 75228  47812338        4     702706.0       ['none', ['190']]
# 75229  47325063        4    1130043.0      [['1052'], 'none']
# 75230  48032031        4     910803.0        ['none', 'none']
# 75231  48609258        4     570041.0       [['262'], 'none']
#
#       author_1_ru last name author_1_ru initials
# 0                    Кийков                 А.В.  \
# 1                  Салагаев                   А.
# 2                  Семченко                 И.В.
# 3                   Хагуров                 Т.А.
# 4                    Елишев                 С.О.
# ...                     ...                  ...
# 75227                  none                 none
# 75228                  none                 none
# 75229             Касаткина                  М.И
# 75230                Дыжова                 А.А.
# 75231              Филипова                 А.Г.
#
#                                  author_1_ru affiliation
# 0      ['Белгородский государственный технологический...  \
# 1                                                   none
# 2           ['Белгородский государственный университет']
# 3              ['Кубанский государственный университет']
# 4                           ['МГУ им. М.В. Ломоносова?']
# ...                                                  ...
# 75227                                               none
# 75228                                               none
# 75229  ['Калужский государственный университет им. К....
# 75230                                               none
# 75231        ['Дальневосточный федеральный университет']
#
#       author_1_eng last name author_1_eng initials
# 0                     Kiykov                  A.V.  \
# 1                   Salagaev                    A.
# 2                  Semchenko                  I.V.
# 3                    Hagurov                  T.A.
# 4                    Elishev                  S.O.
# ...                      ...                   ...
# 75227          Shayakhmetova                  R.R.
# 75228                Kretser                 I.Yu.
# 75229              Kasatkina                   M.I
# 75230                Dyzhova                  A.A.
# 75231               Filipova                  A.G.
#
#                                 author_1_eng affiliation  ... genre_id cited
# 0      ['Belgorod State Technological University name...  ...        4     3  \
# 1                                                   none  ...        4     0
# 2                                                   none  ...        4     0
# 3                                                   none  ...        4     0
# 4                                                   none  ...        4    22
# ...                                                  ...  ...      ...   ...
# 75227                     ['Bashkiria State University']  ...        4     0
# 75228              ['Saint-Petersburg State University']  ...        4     0
# 75229                                               none  ...        4     8
# 75230                                               none  ...        4     0
# 75231                                               none  ...        4     4
#
#       corecited parent_id source_id isFT isNEW
# 0           1.0  33649315       NaN    1     0  \
# 1           0.0  33649638       NaN    1     1
# 2           0.0  33649676       NaN    1     1
# 3           0.0  33651468       NaN    1     1
# 4           3.0  33651490       NaN    0     1
# ...         ...       ...       ...  ...   ...
# 75227       0.0  48109812      17.0    1     1
# 75228       0.0  46863661      17.0    0     1
# 75229       0.0  47325062      17.0    0     1
# 75230       0.0  48032030      17.0    0     1
# 75231       0.0  34474594      17.0    0     1
#
#                                           link
# 0      http://elibrary.ru/item.asp?id=15485609  \
# 1      http://elibrary.ru/item.asp?id=15488335
# 2      http://elibrary.ru/item.asp?id=15488853
# 3      http://elibrary.ru/item.asp?id=15500786
# 4      http://elibrary.ru/item.asp?id=15501422
# ...                                        ...
# 75227  http://elibrary.ru/item.asp?id=48109813
# 75228  http://elibrary.ru/item.asp?id=47812338
# 75229  http://elibrary.ru/item.asp?id=47325063
# 75230  http://elibrary.ru/item.asp?id=48032031
# 75231  http://elibrary.ru/item.asp?id=48609258
#
#                                                      url
# 0                                                   none  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 75227  https://revista.fct.unesp.br/index.php/Nuances...
# 75228  https://polarjournal.org/2020/03/18/migration-...
# 75229                                                NaN
# 75230                                                NaN
# 75231                                                NaN
#
#                                                      ref
# 0      Кийков, А.В. СОСТОЯНИЕ И ТЕНДЕНЦИИ СЕТЕВОГО ВЗ...
# 1      Салагаев, А. КУЛЬТУРНАЯ И РЕЛИГИОЗНАЯ СИТУАЦИЯ...
# 2      Семченко, И.В. ПРОБЛЕМЫ СОЦИАЛЬНОЙ АДАПТАЦИИ Г...
# 3      Хагуров, Т.А. Современная культура и воспитани...
# 4      Елишев, С.О. Формирование ценностных ориентаци...
# ...                                                  ...
# 75227  VALUES OF SELF-PRESERVING BEHAVIOR IN THE SYST...
# 75228  Kretser, I.Y. Domestic Economies: Women, Work,...
# 75229  Касаткина, М.И. Организация работы с пожилыми ...
# 75230  Дыжова, А.А. Особенности правовой социализации...
# 75231  Филипова, А.Г. Городская "доброжелательность" ...
#
# [75232 rows x 105 columns]

# %% [markdown]
# ### 0. Создание пользовательских функций для работы с данными
#
# Перед тем, как работать дальше, я создаю несколько функций, проверяющих язык написания текста и функций, транслитерирующих текст. Это нужно, тк в редких случаях в ячейке с русскоязычными инцииалами могут быть записаны англоязычные, в тексте с англоязычными - русскоязычные, и так далее.

# %%
def is_in_english(text, alphabet=set('abcdefghijklmnopqrstuvwxyz')):
    return not alphabet.isdisjoint(text.lower())
print(is_in_english('test')) # True
print(is_in_english('тест')) # False
print(is_in_english('123Ы')) # False
print(is_in_english('Фаmilia')) # есть английские символы, True
print(is_in_english(''))     # False
# Out:
# True
# False
# False
# True
# False

# %%
def is_in_russian(text, alphabet=set('абвгдеёжзийклмнопрстуфхцчшщъыьэюя')):
    return not alphabet.isdisjoint(text.lower())

print(is_in_russian('test')) # False
print(is_in_russian('тест')) # True
print(is_in_russian('123Ы')) # True
print(is_in_russian('Фаmilia')) # есть русские символы, True
print(is_in_russian(''))     # False
# Out:
# False
# True
# True
# True
# False

# %%
# использую готовую библиотеку транслитерации
#!pip install transliterate
from transliterate import translit
text = 'Lorem ipsum dolor sit amet'
ru_text = translit(text, 'ru') # text мы транслитерируем на русский
ru_text
# Out:
# 'Лорем ипсум долор сит амет'

# %%
def transliterate_to_russian(text, capitalize=True):
    ru_text = translit(text, 'ru').lower() # text мы транслитерируем на русский
    ru_text = ru_text.replace('кх', 'х').replace('ыа', 'я').replace('ые', 'ь').replace('ыу', 'ю') # меняем 
    ru_text = ru_text.replace('ьва', 'ева')
    if capitalize == True:
        ru_text = ru_text.capitalize()
    return ru_text

# %%
def transliterate_to_english(text, capitalize=True):
    eng_text = translit(text, 'ru', reversed=True).lower() # text мы транслитерируем на английский
    if capitalize == True:
        eng_text = eng_text.capitalize()
    return eng_text

# %% [markdown]
# ## Часть 1. Содержание предобработки:
#
#
# * **Шаг 0.** Ранее я поняла, что у нас двумя способами маркировались отсутствующие данные: как `np.nan` (фильтруется через `.isnull() == True`) и через `none`.  `none` встречается чаще, просто отсутствующие данные встречаются реже. Поэтому **выше была проведена замена отсутствующих значений (`np.nan`)на `none`**;
#
#
# * **Шаг 1.** Нужно во всех столбцах `author_{i}_eng initials` заменить n. на none; если не с n. - то просто привести к виду `X.X.`;
#
#
# * **Шаг 2.** Заменить в столбцах `author_{i}_ru initials` строки где с малой строки: если начинаются на n. - на none; если не с n. - то просто привести к виду N.N. **Далее произвести транслитерацию** - `author_{i}_ru initials` в `author_{i}_eng initials` для таких наблюдений;
#
#
# * **Шаг 3**. В тех инициалах, где по столбцу `author_{i}_ru_initials` присутствует русская буква `X` и на ее месте в столбце `author_{i}_eng_initials` находится английская `k`, следует заменить ее на `h`;
#
#
# * **Шаг 4**. Исследовать проблемные фамилии (в которых присутствуют точки) по всем столбцам `author_{i}_ru last name` и `author_{i}eng last name`: взять из фамилий инициалы и поставить их на место инициалов `author_{i}_{j} initials`, а сами инициалы удалить из фамилий `author_{i}_{j} last name`. **Далее произвести транслитерацию** - `author_{i}_ru initials` в `author_{i}_eng initials` для таких наблюдений;
#
#
# * **Шаг 5**. Поработать с проблемными инициалами `author_{i}_ru initials` там где более двух точек в инициалах: делим строку по точкам, используем .strip(), берем только те значения, длина которых меньше двух(Так, Н.Г.-К. станет Н.Г.-К; а вот Р.А. Роман Александрович преобразуется просто в Р.А.). Транслитерировать инициалы в `author_{i}_eng initials`;
#
#
# * **Шаг 6**. Транслитерировать с английского на русский в столбцах `author_{i}_ru last name` и `author_{i}_ru initials`, где указан английский, а не русский текст.

# %% [markdown]
# ### Шаг 0.  Замена `np.nan` на строку `none`

# %%
import numpy as np
df = df.replace(np.nan, 'none') # замена np.nan на 'none'

# %% [markdown]
# ### Шаг 1. Транслитерация с английского на русский в столбцах: обработка `author_{i}_eng initials`
#
# В некоторых столбцах с пометкой `ru` на самом деле содержатся написанные на английском фамилии. Надо перевести все `last name` и `initials` в столбцах со всеми `8` авторами с пометкой `ru`.
#
# Что будем делать? Во всех столбцах `author_{i}_eng initials` заменю `n.` на `none` (есть предположение, что в рамках небольшой нашей собственной предварительной обработки значение `none` было приведено к `n.`), и приведу к прописным буквам.

# %%
# пример проблемы - в столбце с русскими фамилиями стоят фамилии на английиском
for i in df['author_1_ru last name'][:25000]:
    if is_in_russian(i) != True and i != 'none':
        print(i)
# Out:
# Kahaeba
# Tatarko
# Kulyasov
# Kulyasov
# Sadykova

# %%
for i in ['Попова', 'Колосова', 'Львов']:
    print(transliterate_to_english(i)) # пример работы функции
# Out:
# Popova
# Kolosova
# L'vov

# %%
# пример транслитерации с английского на русский
for i in df[df['author_1_ru last name'] == 'none']['author_1_eng last name'].tolist()[50:60]:
    try:
        print(f'Фамилия: {i}, перевод с помощью translator: {transliterate_to_russian(i)}')
    except:
        print(f'Не получилось перевести {i}')
# Out:
# Фамилия: Vasiliev, перевод с помощью translator: Василиев
# Фамилия: Romashkina, перевод с помощью translator: Ромашкина
# Фамилия: Tuhvatullina, перевод с помощью translator: Тухватуллина
# Фамилия: Turdubayeva, перевод с помощью translator: Турдубаева
# Фамилия: Lvov, перевод с помощью translator: Лвов
# Фамилия: Kolosova, перевод с помощью translator: Колосова
# Фамилия: Dolomatov, перевод с помощью translator: Доломатов
# Фамилия: Klimyuk, перевод с помощью translator: Климюк
# Фамилия: Salova, перевод с помощью translator: Салова
# Фамилия: Kornilova, перевод с помощью translator: Корнилова

# %%
def change_value(x):
    if x == 'n.' or x == 'none':
        return 'none'
    else:
        return x.upper()
    
for i in range(1, 8+1):
    df[f'author_{i}_eng initials'] = df[f'author_{i}_eng initials'].apply(lambda x: change_value(x))

# %% [markdown]
# ### Шаг 2 – обработка `author_{i}_ru initials` и `author_{i}_eng initials`
#
# Заменить в столбцах `author_{i}_ru initials` строки где с малой строки: если начинаются на n. - на none; если не с n. - то просто привести к виду `X.X`. **Далее произвести транслитерацию** - `author_{i}_ru initials` в `author_{i}_eng initials` для таких наблюдений;

# %%
# Демонстрация проблемы
for i in df['author_1_ru initials']:
    if i.islower() == True and i != 'none':
        print(i)
# Out:
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# к.соц.н.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# n.
# т.к.
# n.
# д.с.
# n.
# е.ю.
# n.
# n.
# n.
# n.
# n.
# n.

# %%
for i in range(1, 8+1):
    col_index = i
    
    for j in range(df.shape[0]):
        
        row_index = j
        current_ru_initials = df.loc[j, f'author_{i}_ru initials']
        # если наши инициалы написаны с маленькой буквы
        if current_ru_initials.islower() == True:
            # если у нас инициалы n. или none
            if current_ru_initials == 'n.' or current_ru_initials == 'none' or current_ru_initials == 'к.соц.н':
                df.loc[j, f'author_{i}_ru initials'] = 'none' # присваиваем none
                df.loc[j, f'author_{i}_eng initials'] = 'none' # присваиваем none
            else: # если не none, просто с маленькой буквы
                df.loc[j, f'author_{i}_ru initials'] = current_ru_initials.upper() # по-русскки - поднимаем вверх
                df.loc[j, f'author_{i}_eng initials'] = transliterate_to_english(current_ru_initials.upper()) # транслитерируем на английский

# %%
# Демонстрация проблемы: РЕШЕНО. 
for i in df['author_1_ru initials']:
    if i.islower() == True and i != 'none':
        print(i)

# %% [markdown]
# Теперь у нас нет проблемных значений с маленькой буквы в колонках с русскими инициалами.

# %% [markdown]
# ### Шаг 3  – работа с русской Х в  `author_{i}_ru_initials` и  `author_{i}_eng_initials`
# В тех инициалах, где по столбцу `author_{i}_ru_initials` присутствует русская буква `X` и на ее месте в столбце `author_{i}_eng_initials` находится английская `k`, следует заменить ее на `h`. Это возникает, вероятно, из-за специфики транслитерации.

# %%
for i in range(1, 8+1):
    index_col = i # идем по 8 столбцам с авторами
    for j in range(df.shape[0]):
        index_row = j  # смотрим на конкретную строчку
        current_russian_initials = df.loc[index_row, f'author_{i}_ru initials']
        if 'х' in current_russian_initials.lower(): # если в инициалах есть х
            # то в английской транслитерации заменяем k на h (х транслитерируется как кх)
            df.loc[index_row, f'author_{i}_eng initials'] = df.loc[index_row, f'author_{i}_eng initials'].replace('k', 'h').upper()

# %% [markdown]
# ### Шаг 4 – предобработка фамилий `author_{i}_ru last name` и `author_{i}_eng last name`
# Исследовать проблемные фамилии (в которых присутствуют точки) по всем столбцам `author_{i}_ru last name` и `author_{i}eng last name`: взять из фамилий инициалы и поставить их на место инициалов `author_{i}_{j} initials`, а сами инициалы удалить из фамилий `author_{i}_{j} last name`. **Далее произвести транслитерацию** - `author_{i}_ru initials` в `author_{i}_eng initials` для таких наблюдений;

# %%
# Демонстрация проблемы - иногда в фамилиях (last name) записаны еще и инициалы
for i in df['author_1_ru last name']:
    if '.' in i:
        print(i)
# Out:
# Савченко Е.
# Шилова.
# Крикунова Ю.А.
# Т.И. Морозова
# Б.Усманов
# Шафранов-Куцев Г.Ф.
# В.Н. Круглиевский
# Сотникова Н.Н.
# Ханаху Р.А
# Ин Д.В
# Воронежский И.С.
# Двирник. Ю.С
# Попова.В.В
# Лук. П.А

# %%
# Пример - как это будет работать; разобраны разные сценарии
# case 1 - "Иванов И.И" в author_{i}_ru last name
# case 2 - "Иванов." в author_{i}_ru last name
# case 3 - "И.И.Иванов." в author_{i}_ru last name

for i in df['author_1_ru last name']:
    if '.' in i:
        if ' ' in i:
            last_name_list = i.split()
            last_name_list = sorted(last_name_list, key=lambda x: x.isupper()) # сортируем по в вверхнем регистре или нет
            last_name = last_name_list[0].strip('.') # корректная фамилия
            initials = '.'.join(last_name_list[1:]).upper() # корректные инициалы
            print('case 1')
            print(f'was {i}, became {last_name},\nwill transfer to initials {initials}', end='\n\n')
            
        else:
            last_name_list = i.split('.')
            last_name_list = sorted(last_name_list, key=lambda x: x.isupper()) # сортируем: сперва будут значения которые не полностью капслоком, потом - такие
            if len(last_name_list) == 2 and last_name_list[1] == '': # если у нас там только фамилия (пример: Шилова. -> Шилова)
                new_last_name = last_name_list[0]
                print('case 2')
                print(f'was {i}, became {new_last_name}', end='\n\n')
            else:
                new_last_name = last_name_list[0].capitalize()
                new_initials = '.'.join(last_name_list[1:]).upper() + '.'
                print('case3')
                print(f'was {i}, became {new_last_name},\nwill transfer to initials {new_initials}', end='\n\n')
# Out:
# case 1
# was Савченко Е., became Савченко,
# will transfer to initials Е.
#
# case 2
# was Шилова., became Шилова
#
# case 1
# was Крикунова Ю.А., became Крикунова,
# will transfer to initials Ю.А.
#
# case 1
# was Т.И. Морозова, became Морозова,
# will transfer to initials Т.И.
#
# case3
# was Б.Усманов, became Усманов,
# will transfer to initials Б.
#
# case 1
# was Шафранов-Куцев Г.Ф., became Шафранов-Куцев,
# will transfer to initials Г.Ф.
#
# case 1
# was В.Н. Круглиевский, became Круглиевский,
# will transfer to initials В.Н.
#
# case 1
# was Сотникова Н.Н., became Сотникова,
# will transfer to initials Н.Н.
#
# case 1
# was Ханаху Р.А, became Ханаху,
# will transfer to initials Р.А
#
# case 1
# was Ин Д.В, became Ин,
# will transfer to initials Д.В
#
# case 1
# was Воронежский И.С., became Воронежский,
# will transfer to initials И.С.
#
# case 1
# was Двирник. Ю.С, became Двирник,
# will transfer to initials Ю.С
#
# case3
# was Попова.В.В, became Попова,
# will transfer to initials В.В.
#
# case 1
# was Лук. П.А, became Лук,
# will transfer to initials П.А

# %%
for i in range(1, 8+1):
    index_col = i
    
    for j in range(df.shape[0]):
        index_row = j
        current_last_name_ru = df.loc[index_row, f'author_{index_col}_ru last name']
        if '.' in current_last_name_ru:
            
            # если у нас в фамилии и имени есть пробелы
            if ' ' in current_last_name_ru:
                last_name_list = current_last_name_ru.split()
                last_name_list = sorted(last_name_list, key=lambda x: x.isupper()) # сортируем по в вверхнем регистре или нет
                
                last_name = last_name_list[0].strip('.') # корректная фамилия
                initials = '.'.join(last_name_list[1:]).upper() # корректные инициалы
                
                # присваиваем значения: выносим из фамилии инициалы в свой столбец; у себя оставляем только фамилию
                df.loc[index_row, f'author_{index_col}_ru last name'] = last_name
                df.loc[index_row, f'author_{index_col}_ru initials'] = initials
                # транслитерируем с русского на англиийский
                df.loc[index_row, f'author_{index_col}_eng last name'] = transliterate_to_english(last_name)
                df.loc[index_row, f'author_{index_col}_eng last name'] = transliterate_to_english(initials).upper()
            else:
                last_name_list = current_last_name_ru.split('.') # разбиваем по точке
                last_name_list = sorted(last_name_list, key=lambda x: x.isupper()) # сортируем: сперва будут значения которые не полностью капслоком, потом - такие
                
                if len(last_name_list) == 2 and last_name_list[1] == '': # если у нас там только фамилия (пример: Шилова. -> Шилова)
                    new_last_name = last_name_list[0]
                    # просто обновляем фамилию и транслитерируем ее на английский
                    df.loc[index_row, f'author_{index_col}_ru last name'] = new_last_name
                    df.loc[index_row, f'author_{index_col}_eng last name'] = transliterate_to_english(last_name)
                else:
                    # а если у нас там и фамилия, и иницииалы (пример: Попова.В.В -> [Попова,В,В])
                    new_last_name = last_name_list[0].capitalize()
                    new_initials = '.'.join(last_name_list[1:]).upper() + '.'
                    
                    # теперь выносим из ячейки инициалы в русские инициалы, оставляем только фамилию
                    df.loc[index_row, f'author_{index_col}_ru last name'] = new_last_name
                    df.loc[index_row, f'author_{index_col}_ru initials'] = new_initials
                    # потом все это дело транслитерируем на английиский
                    df.loc[index_row, f'author_{index_col}_eng last name'] = transliterate_to_english(new_last_name)
                    df.loc[index_row, f'author_{index_col}_eng last name'] = transliterate_to_english(new_initials).upper()

# %%
# Проблема - решена! - ничего не печатается
for i in df['author_1_ru last name']:
    if '.' in i:
        print(i)

# %% [markdown]
# ### Шаг 5 - работа с инициалами в `author_{i}_ru initials`, где указано больше двух точек
#
# Задача на этом шаге – поработать с проблемными инициалами `author_{i}_ru initials` там где более двух точек в инициалах: делим строку по точкам, используем метод строк `.strip()`, берем только те значения, длина которых меньше двух. Для примера: `Н.Г.-К.` останется `Н.Г.-К`, но `Р.А. Роман Александрович` преобразуется просто в `Р.А.`. После этих преобразований мы транслитерируем инициалы в `author_{i}_eng initials`.

# %%
# демонстрация проблемы - иногда подозрительно много точек 
for i in df['author_1_ru initials']:
    if i.count('.') > 2:
        print(i)
# Out:
# к.соц.н.
# Н.Г.-К.
# М.С.-Г.
# З.Х.-М.
# Н. Г.-К.
# О.-В.В.
# Э.А.-О.
# Б.М.-Г.
# И.И. Биктагирова М.К.
# Н. С.-Х.
# Н. С.-Х.
# М.-П.Б.
# В. М.I.1О8I.
# С.-А. И.
# Е.А. Савостьянов В.М.
# А.А.Х.
# З. Х.-М.
# Р.А.-А.

# %%
# демонстрация проблемы и работы
for i in df['author_1_ru initials']:
    if len(i) > 4:
        # пример1 - "Р. Д."
        if len(i.strip(',')) in [4, 5] and i.strip(',')[-1] == '.' and i[1] == '.' and i[2] == ' ':
            new_initials = i.replace(' ', '').strip(',')
            print(i)
            print(new_initials)
            print()
        # пример 2: Огребор О.Д.
        elif len(i.split()) == 2 and i.count('.') > 1 and '-' not in i:
            print(i)
            print('Нельзя преобразовать, нужно игнорировать')
            print()
        
        # пример 3: Владимир И.
        elif len(i.split()) == 2 and '.' in i and len(i) != 5:
            print(i)
            mylist = i.strip('.').split()
            mylist = [i.replace('.', '') for i in mylist]
            print(mylist)
            new_initials = []
            for z in mylist:
                # пример: Дмитрий
                if '(' not in z and '-' not in z and '?' not in z:
                    new = z[0].upper()
                    new_initials.append(new)
                # пример: Азер-кызы 
                elif '-' in z:
                    first_symbol = z[0].upper()
                    second_symbol = z[z.index('-')+1].upper()
                    new = f'{first_symbol}.-{second_symbol}.'
                    new_initials.append(new)
                    
                elif '(' in z or '?' in z:
                    new_initials.append(z) # просто добавляем к новым инициалам
            print(new_initials)
            new_initials = '.'.join(new_initials)
            if new_initials[-1] != '.':
                new_initials += '.'
            print(new_initials)
            print()
# Out:
# Т. Азер-кызы
# ['Т', 'Азер-кызы']
# ['Т', 'А.-К.']
# Т.А.-К.
#
# Екатерина Михайловна.
# ['Екатерина', 'Михайловна']
# ['Е', 'М']
# Е.М.
#
# Дмитрий Сергеевич.
# ['Дмитрий', 'Сергеевич']
# ['Д', 'С']
# Д.С.
#
# Вл. А.
# Нельзя преобразовать, нужно игнорировать
#
# Уэсли У.
# ['Уэсли', 'У']
# ['У', 'У']
# У.У.
#
# Александр Ф.
# ['Александр', 'Ф']
# ['А', 'Ф']
# А.Ф.
#
# Данило Ж.
# ['Данило', 'Ж']
# ['Д', 'Ж']
# Д.Ж.
#
# Джеймс Б.
# ['Джеймс', 'Б']
# ['Д', 'Б']
# Д.Б.
#
# Пол Ф.
# ['Пол', 'Ф']
# ['П', 'Ф']
# П.Ф.
#
# Айгуль Ф.
# ['Айгуль', 'Ф']
# ['А', 'Ф']
# А.Ф.
#
# Вячеслав Вениаминович.
# ['Вячеслав', 'Вениаминович']
# ['В', 'В']
# В.В.
#
# Андрей Н.
# ['Андрей', 'Н']
# ['А', 'Н']
# А.Н.
#
# Го Ун.
# ['Го', 'Ун']
# ['Г', 'У']
# Г.У.
#
# З. Х-М
# ['З', 'Х-М']
# ['З', 'Х.-М.']
# З.Х.-М.
#
# Н. Г.-К.
# ['Н', 'Г-К']
# ['Н', 'Г.-К.']
# Н.Г.-К.
#
# Веков А.И.
# Нельзя преобразовать, нужно игнорировать
#
# Джон Дж.
# ['Джон', 'Дж']
# ['Д', 'Д']
# Д.Д.
#
# Дмитрий Юрьевич.
# ['Дмитрий', 'Юрьевич']
# ['Д', 'Ю']
# Д.Ю.
#
# Сергей Александрович.
# ['Сергей', 'Александрович']
# ['С', 'А']
# С.А.
#
# Екатерина В.ячеславовна
# ['Екатерина', 'Вячеславовна']
# ['Е', 'В']
# Е.В.
#
# Ирина Марковна.
# ['Ирина', 'Марковна']
# ['И', 'М']
# И.М.
#
# Виктор Григорьевич.
# ['Виктор', 'Григорьевич']
# ['В', 'Г']
# В.Г.
#
# (де) В.
# ['(де)', 'В']
# ['(де)', 'В']
# (де).В.
#
# Аревик В.
# ['Аревик', 'В']
# ['А', 'В']
# А.В.
#
# Одриосола М.С.
# Нельзя преобразовать, нужно игнорировать
#
# Шади А.А.
# Нельзя преобразовать, нужно игнорировать
#
# Наталья Л.
# ['Наталья', 'Л']
# ['Н', 'Л']
# Н.Л.
#
# Г. С-Х.
# ['Г', 'С-Х']
# ['Г', 'С.-Х.']
# Г.С.-Х.
#
# Н. С.-Х.
# ['Н', 'С-Х']
# ['Н', 'С.-Х.']
# Н.С.-Х.
#
# Филип А.
# ['Филип', 'А']
# ['Ф', 'А']
# Ф.А.
#
# Марина Евгеньевна.
# ['Марина', 'Евгеньевна']
# ['М', 'Е']
# М.Е.
#
# Евгений В.
# ['Евгений', 'В']
# ['Е', 'В']
# Е.В.
#
# Н. С.-Х.
# ['Н', 'С-Х']
# ['Н', 'С.-Х.']
# Н.С.-Х.
#
# Дмитрий В.
# ['Дмитрий', 'В']
# ['Д', 'В']
# Д.В.
#
# Наталья В.
# ['Наталья', 'В']
# ['Н', 'В']
# Н.В.
#
# Хасан М.А.
# Нельзя преобразовать, нужно игнорировать
#
# Петр В.
# ['Петр', 'В']
# ['П', 'В']
# П.В.
#
# Константин Б.
# ['Константин', 'Б']
# ['К', 'Б']
# К.Б.
#
# Наиде С.
# ['Наиде', 'С']
# ['Н', 'С']
# Н.С.
#
# Константин Б.
# ['Константин', 'Б']
# ['К', 'Б']
# К.Б.
#
# Светлана Владимировна.
# ['Светлана', 'Владимировна']
# ['С', 'В']
# С.В.
#
# Алексей Г.
# ['Алексей', 'Г']
# ['А', 'Г']
# А.Г.
#
# Григорий Б.
# ['Григорий', 'Б']
# ['Г', 'Б']
# Г.Б.
#
# Владимир В.
# ['Владимир', 'В']
# ['В', 'В']
# В.В.
#
# Давид Г.
# ['Давид', 'Г']
# ['Д', 'Г']
# Д.Г.
#
# Виктор С.
# ['Виктор', 'С']
# ['В', 'С']
# В.С.
#
# Павел Е.
# ['Павел', 'Е']
# ['П', 'Е']
# П.Е.
#
# Гурминдер К.
# ['Гурминдер', 'К']
# ['Г', 'К']
# Г.К.
#
# (де) В.
# ['(де)', 'В']
# ['(де)', 'В']
# (де).В.
#
# Я-А. В.
# ['Я-А', 'В']
# ['Я.-А.', 'В']
# Я.-А..В.
#
# В. М.I.1О8I.
# Нельзя преобразовать, нужно игнорировать
#
# Л. С-К.
# ['Л', 'С-К']
# ['Л', 'С.-К.']
# Л.С.-К.
#
# Лида Увайсовна.
# ['Лида', 'Увайсовна']
# ['Л', 'У']
# Л.У.
#
# Лида Увайсовна.
# ['Лида', 'Увайсовна']
# ['Л', 'У']
# Л.У.
#
# Олег Н.
# ['Олег', 'Н']
# ['О', 'Н']
# О.Н.
#
# Евгения А.
# ['Евгения', 'А']
# ['Е', 'А']
# Е.А.
#
# Анатолий Ш.
# ['Анатолий', 'Ш']
# ['А', 'Ш']
# А.Ш.
#
# Алексей С.
# ['Алексей', 'С']
# ['А', 'С']
# А.С.
#
# Елена А.
# ['Елена', 'А']
# ['Е', 'А']
# Е.А.
#
# Павел М.
# ['Павел', 'М']
# ['П', 'М']
# П.М.
#
# Алина В.
# ['Алина', 'В']
# ['А', 'В']
# А.В.
#
# Надежда Ю.
# ['Надежда', 'Ю']
# ['Н', 'Ю']
# Н.Ю.
#
# Леена М.
# ['Леена', 'М']
# ['Л', 'М']
# Л.М.
#
# Юрий Л.
# ['Юрий', 'Л']
# ['Ю', 'Л']
# Ю.Л.
#
# Алексей С.
# ['Алексей', 'С']
# ['А', 'С']
# А.С.
#
# Николай И.
# ['Николай', 'И']
# ['Н', 'И']
# Н.И.
#
# Елена А.
# ['Елена', 'А']
# ['Е', 'А']
# Е.А.
#
# Хьюберт М.
# ['Хьюберт', 'М']
# ['Х', 'М']
# Х.М.
#
# ? С.С.
# Нельзя преобразовать, нужно игнорировать
#
# Владимир И.
# ['Владимир', 'И']
# ['В', 'И']
# В.И.
#
# С.-А. И.
# ['С-А', 'И']
# ['С.-А.', 'И']
# С.-А..И.
#
# Дарья С.
# ['Дарья', 'С']
# ['Д', 'С']
# Д.С.
#
# Анастасия Александровна.
# ['Анастасия', 'Александровна']
# ['А', 'А']
# А.А.
#
# И. Д.
# И.Д.
#
# Н. С.
# Н.С.
#
# Г. Г.
# Г.Г.
#
# З. Х.-М.
# ['З', 'Х-М']
# ['З', 'Х.-М.']
# З.Х.-М.
#
# Евгений В.
# ['Евгений', 'В']
# ['Е', 'В']
# Е.В.
#
# Елена А.
# ['Елена', 'А']
# ['Е', 'А']
# Е.А.
#
# Денис Ю.
# ['Денис', 'Ю']
# ['Д', 'Ю']
# Д.Ю.
#
# Т. В.
# Т.В.
#
# Е. И.
# Е.И.
#
# Д. В.
# Д.В.
#
# Денис Ю.
# ['Денис', 'Ю']
# ['Д', 'Ю']
# Д.Ю.
#
# Л. И.
# Л.И.
#
# Р. Мл.
# Нельзя преобразовать, нужно игнорировать
#
# Е. М.
# Е.М.
#
# Галина С.
# ['Галина', 'С']
# ['Г', 'С']
# Г.С.
#
# Г. И.
# Г.И.
#
# В. Г.
# В.Г.
#
# В. Ю.,
# В.Ю.
#
# Д. Н.
# Д.Н.
#
# Алан Л.
# ['Алан', 'Л']
# ['А', 'Л']
# А.Л.
#
# Ольга Л.
# ['Ольга', 'Л']
# ['О', 'Л']
# О.Л.
#
# И. В.
# И.В.
#
# Ю. Г.
# Ю.Г.
#
# Любовь А.
# ['Любовь', 'А']
# ['Л', 'А']
# Л.А.
#
# Е. В.
# Е.В.
#
# Л. Н.
# Л.Н.
#
# Т. А.
# Т.А.
#
# Мария Александровна.
# ['Мария', 'Александровна']
# ['М', 'А']
# М.А.
#
# Я. А.
# Я.А.
#
# Виктория Ю.
# ['Виктория', 'Ю']
# ['В', 'Ю']
# В.Ю.
#
# И. А.
# И.А.
#
# Мария Д.
# ['Мария', 'Д']
# ['М', 'Д']
# М.Д.
#
# Ю. С.
# Ю.С.
#
# О. А.
# О.А.
#
# А. В.
# А.В.
#
# О. Н.
# О.Н.
#
# В. А.
# В.А.
#
# В. Д.
# В.Д.
#
# А. М.
# А.М.
#
# Н. К.
# Н.К.
#
# Сергей В.
# ['Сергей', 'В']
# ['С', 'В']
# С.В.
#
# Неманя Б.
# ['Неманя', 'Б']
# ['Н', 'Б']
# Н.Б.
#
# Евгений М.
# ['Евгений', 'М']
# ['Е', 'М']
# Е.М.
#
# Татьяна Н.
# ['Татьяна', 'Н']
# ['Т', 'Н']
# Т.Н.
#
# Д. В.
# Д.В.
#
# Андрей Г.
# ['Андрей', 'Г']
# ['А', 'Г']
# А.Г.
#
# Ксения Олеговна.
# ['Ксения', 'Олеговна']
# ['К', 'О']
# К.О.
#
# Х. В.
# Х.В.
#
# Д. Р.
# Д.Р.
#
# В. Д.
# В.Д.
#
# М. В.
# М.В.
#
# Анна Л.
# ['Анна', 'Л']
# ['А', 'Л']
# А.Л.
#
# Алан Л.
# ['Алан', 'Л']
# ['А', 'Л']
# А.Л.
#
# Иван В.
# ['Иван', 'В']
# ['И', 'В']
# И.В.
#
# Михаил В.
# ['Михаил', 'В']
# ['М', 'В']
# М.В.
#
# Ю. И.
# Ю.И.
#
# Наталья В.
# ['Наталья', 'В']
# ['Н', 'В']
# Н.В.
#
# Елена А.
# ['Елена', 'А']
# ['Е', 'А']
# Е.А.
#
# Владислав А.
# ['Владислав', 'А']
# ['В', 'А']
# В.А.
#
# Наталья М.
# ['Наталья', 'М']
# ['Н', 'М']
# Н.М.
#
# Дмитрий В.
# ['Дмитрий', 'В']
# ['Д', 'В']
# Д.В.
#
# Юлия В.
# ['Юлия', 'В']
# ['Ю', 'В']
# Ю.В.
#
# С. Д.
# С.Д.
#
# Евгений Я.
# ['Евгений', 'Я']
# ['Е', 'Я']
# Е.Я.
#
# О. А.
# О.А.
#
# Илья В.
# ['Илья', 'В']
# ['И', 'В']
# И.В.
#
# Ирина С.
# ['Ирина', 'С']
# ['И', 'С']
# И.С.
#
# Яна Д.
# ['Яна', 'Д']
# ['Я', 'Д']
# Я.Д.
#
# Георгий С.
# ['Георгий', 'С']
# ['Г', 'С']
# Г.С.
#
# Гарри Г.
# ['Гарри', 'Г']
# ['Г', 'Г']
# Г.Г.
#
# Дмитрий В.
# ['Дмитрий', 'В']
# ['Д', 'В']
# Д.В.
#
# Наталия М.
# ['Наталия', 'М']
# ['Н', 'М']
# Н.М.
#
# Екатерина Д.
# ['Екатерина', 'Д']
# ['Е', 'Д']
# Е.Д.
#
# Александр Ф.
# ['Александр', 'Ф']
# ['А', 'Ф']
# А.Ф.
#
# Огбебор О.Д.
# Нельзя преобразовать, нужно игнорировать
#
# Анна А.
# ['Анна', 'А']
# ['А', 'А']
# А.А.
#
# С. Б.
# С.Б.
#
# Е. А.
# Е.А.
#
# К. М.
# К.М.
#
# А. С.
# А.С.
#
# Я. В.
# Я.В.
#
# С. К.
# С.К.
#
# А. Н.
# А.Н.
#
# М. Л.
# М.Л.
#
# О. Ю.
# О.Ю.
#
# А. Е.
# А.Е.
#
# Н. Б.
# Н.Б.
#
# Е. С.
# Е.С.
#
# Д. В.
# Д.В.

# %%
for i in range(1, 8+1):
    index_col = i
    
    for j in range(df.shape[0]):
        current_initials = df.loc[j, f'author_{index_col}_ru initials']
        
        # случай 1: инициалы "Д. Р.", нужно просто убрать пробел между
        if len(current_initials.strip(',')) in [4, 5] and current_initials.strip(',')[-1] == '.' and current_initials[1] == '.' and current_initials[2] == ' ':
            new_initials = current_initials.replace(' ', '').strip(',')
            
            # теперь! меняем инициалы нормальные; русские инициалы транслитерируем на английский
            df.loc[j, f'author_{index_col}_ru initials'] = new_initials
            df.loc[j, f'author_{index_col}_eng initials'] = transliterate_to_english(new_initials).upper()

        # пример 2: Огребор О.Д.
        elif len(current_initials.split()) == 2 and current_initials.count('.') > 1 and '-' not in current_initials:
            # преобразовать невозможно, пропускаем
            pass
        
        # пример 3: "Владимир И." или "Сергей Александрович."
        elif len(current_initials.split()) == 2 and '.' in current_initials and len(current_initials) != 5:
            # делаем список
            mylist = current_initials.strip('.').split()
            mylist = [k.replace('.', '') for k in mylist] # удаляем точки
            new_initials = []
            
            # идем по тому что было в изначальной строке; пример: ['Александр', 'Сергеевич']
            for z in mylist:
                # пример: Дмитрий
                if '(' not in z and '-' not in z and '?' not in z:
                    new = z[0].upper() # на выходе: Д
                    new_initials.append(new) 
                # пример: Азер-кызы 
                elif '-' in z:
                    first_symbol = z[0].upper()
                    second_symbol = z[z.index('-')+1].upper()
                    new = f'{first_symbol}.-{second_symbol}' # результат - 'Т.-К'
                    new_initials.append(new)
                    
                elif '(' in z or '?' in z:
                    new_initials.append(z) # просто добавляем к новым инициалам, пример: (де)

            new_initials = '.'.join(new_initials) # объединяем с точками, теперь это строка а не список
            if new_initials[-1] != '.':
                new_initials += '.'
            # теперь! меняем инициалы нормальные; русские инициалы транслитерируем на английский
            df.loc[j, f'author_{index_col}_ru initials'] = new_initials
            df.loc[j, f'author_{index_col}_eng initials'] = transliterate_to_english(new_initials).upper()

# %%
# демонстрация проблемы и работы: часть проблем ушла, остались вот такие случаи
for i in df['author_1_ru initials']:
    if len(i) > 4 and '-' not in i:
        print(i)
# Out:
# Оксана Геннадьевна Г.
# Вл. А.
# В.Дж.
# Вл.В.
# Р.А. Роман Александрович
# Вл.А.
# О.М.Доктор
# Вл.А.
# Вл.А.
# Веков А.И.
# Оксана.
# Хава Мохаммад М.
# (де).В.
# Одриосола М.С.
# Игнатий (Н.Д. Киут)
# Шади А.А.
# И.И. Биктагирова М.К.
# Алаба.с
# Хасан М.А.
# E.Yu.
# (де).В.
# В. М.I.1О8I.
# I.Yu.
# T.Yu.
# Куюденко А. С.
# ? С.С.
# Е.А. Савостьянов В.М.
# А.А.Х.
# Р. Мл.
# Дж.Б.
# Огбебор О.Д.
# Ya.V.

# %% [markdown]
# ### Шаг 6. Транслитерация с английского на русский в столбцах `author_{i}_ru last name` и `author_{i}_ru initials`, где указан английский, а не русский текст
#
# В наших данных естьь строчки в столбцах с меткой `ru`, где на самом деле содержатся англоязычные строки. Их нужно транслитерировать на русский; изначальное значение строки перенести в английский `author_{i}_eng last name`, а транслитерацию оставить в `author_{i}_ru last name`

# %%
# демонстрация проблемы: на месте РУССКИХ фамилий находятся АНГЛИЙСКИЕ
for i in df['author_1_ru last name']:
    if is_in_russian(i) == False and i != 'none':
        print(i)
# Out:
# Kahaeba
# Tatarko
# Kulyasov
# Kulyasov
# Sadykova
# Goldberg-Altyntsev
# Aksenov
# Cherkasova
# Chahkiev
# Korol
# Andrienko
# Kasymov
# Fomicheva
# Kutsov
# Skorohodova
# Tanatova
# Rohmistrov
# Chankova
# Saari
# Shimanskaya
# Kirilina
# Marshak
# Karstein
# Mikhoparov
# Steklov
# Tanatova
# Fetisova
# Kravchenko
# Igebaeva
# Ediltrudis
# Golovina
# Zakharova
# Cherezov
# Bryazgina
# Galindabaeva
# Mukomel'
# Shnyrenkov
# Anufriev
# Anufriev
# Pryadcko
# Yanitsky
# Arkhipova
# Ermolaeva
# Mannila
# Shimanovskaya

# %%
for i in range(1, 8+1):
    df[f'author_{i}_ru last name'] = df[f'author_{i}_ru last name'].apply(lambda x: transliterate_to_russian(x) if is_in_russian(x) == False and x != 'none' else x)

# %%
# демонстрация проблемы - проблемы больше нет
for i in df['author_1_ru last name']:
    if is_in_russian(i) == False and i != 'none':
        print(i)

# %%
# демонстрация проблемы - РУССКИЕ фамилии там, где должны быть АНГЛИЙСКИЕ
for i in df['author_1_eng last name']:
    if is_in_english(i) == False and i != 'none':
        print(i)
# Out:
# Фролова
# Федорова
# Андриенко
# Тау

# %%
for i in range(1, 8+1):
    df[f'author_{i}_eng last name'] = df[f'author_{i}_eng last name'].apply(lambda x: transliterate_to_english(x) if is_in_english(x) == False and x != 'none' else x)

# %%
# демонстрация проблемы - РУССКИЕ фамилии на месте АНГЛИЙСКИХ - решено!
for i in df['author_1_eng last name']:
    if is_in_english(i) == False and i != 'none':
        print(i)

# %% [markdown]
# ### Часть 1. Проблемы,  требующие ручной обработки
#
# Во-первых, я обнаружила, что есть **Отсутствующие первые авторы у 35 статей**.
# Это статьи с отсутствующими данными по первым авторам находятся по фильтрации `df[df['author_1_eng last name'] == 'none']`. Ручная проверка показывает, что у некоторых авторы все-таки есть имена и данные о них множно получить; пример – первая [статья](https://elibrary.ru/item.asp?id=22649492) из этого списка; по ссылке находятся и данные о статье, и данные об [авторе](https://elibrary.ru/author_profile.asp?authorid=757767). Предлагаемое решение - досбор данных вручную (благо, в нашем случае это 0.05% от всех наших данных - 35 cтатей).

# %%
# Отсутствующие первые авторы у 35 статей 
df[df['author_1_eng last name'] == 'none']
# Out:
#              id  genreId author_1_id author_1_affiliation_id  \
# 18382  22649492        4        none        ['none', 'none']
# 25295  21322840        4        none        ['none', 'none']
# 31014  24710185        4        none        ['none', 'none']
# 32820  21598217        4        none        ['none', 'none']
# 34408  29454634        4        none        ['none', 'none']
# 46775  32383601        4        none        ['none', 'none']
# 56231  37288426        4        none        ['none', 'none']
# 57347  39822976        4        none        ['none', 'none']
# 57399  41138509        4        none        ['none', 'none']
# 58866  41238908        4        none        ['none', 'none']
# 60608  39517318        4        none        ['none', 'none']
# 61830  42738769        4        none        ['none', 'none']
# 62687  44875224        4        none        ['none', 'none']
# 63264  42508991        4        none        ['none', 'none']
# 63802  42441176        4        none        ['none', 'none']
# 64213  43175475        4        none        ['none', 'none']
# 64826  42608206        4        none        ['none', 'none']
# 65733  43321677        4        none        ['none', 'none']
# 68508  44263588        4        none        ['none', 'none']
# 68821  47471630        4        none        ['none', 'none']
# 68868  42608209        4        none        ['none', 'none']
# 68871  42615047        4        none        ['none', 'none']
# 70227  44803080        4        none        ['none', 'none']
# 70240  45583754        4        none        ['none', 'none']
# 70395  46440551        4        none        ['none', 'none']
# 71228  46153777        4        none        ['none', 'none']
# 72270  44643023        4        none        ['none', 'none']
# 72456  45687887        4        none        ['none', 'none']
# 72965  43818817        4        none        ['none', 'none']
# 73333  47447414        4        none        ['none', 'none']
# 73854  46609070        4        none        ['none', 'none']
# 74082  27460771        4        none        ['none', 'none']
# 74152  47744791        4        none        ['none', 'none']
# 74710  43085909        4        none        ['none', 'none']
# 74848  46601010        4        none        ['none', 'none']
#
#       author_1_ru last name author_1_ru initials author_1_ru affiliation  \
# 18382                  none                 none                    none
# 25295                  none                 none                    none
# 31014                  none                 none                    none
# 32820                  none                 none                    none
# 34408                  none                 none                    none
# 46775                  none                 none                    none
# 56231                  none                 none                    none
# 57347                  none                 none                    none
# 57399                  none                 none                    none
# 58866                  none                 none                    none
# 60608                  none                 none                    none
# 61830                  none                 none                    none
# 62687                  none                 none                    none
# 63264                  none                 none                    none
# 63802                  none                 none                    none
# 64213                  none                 none                    none
# 64826                  none                 none                    none
# 65733                  none                 none                    none
# 68508                  none                 none                    none
# 68821                  none                 none                    none
# 68868                  none                 none                    none
# 68871                  none                 none                    none
# 70227                  none                 none                    none
# 70240                  none                 none                    none
# 70395                  none                 none                    none
# 71228                  none                 none                    none
# 72270                  none                 none                    none
# 72456                  none                 none                    none
# 72965                  none                 none                    none
# 73333                  none                 none                    none
# 73854                  none                 none                    none
# 74082                  none                 none                    none
# 74152                  none                 none                    none
# 74710                  none                 none                    none
# 74848                  none                 none                    none
#
#       author_1_eng last name author_1_eng initials author_1_eng affiliation  \
# 18382                   none                  none                     none
# 25295                   none                    n.                     none
# 31014                   none                    n.                     none
# 32820                   none                    n.                     none
# 34408                   none                    n.                     none
# 46775                   none                    n.                     none
# 56231                   none                    n.                     none
# 57347                   none                    n.                     none
# 57399                   none                    n.                     none
# 58866                   none                    n.                     none
# 60608                   none                    n.                     none
# 61830                   none                    n.                     none
# 62687                   none                    n.                     none
# 63264                   none                    n.                     none
# 63802                   none                    n.                     none
# 64213                   none                    n.                     none
# 64826                   none                    n.                     none
# 65733                   none                    n.                     none
# 68508                   none                    n.                     none
# 68821                   none                    n.                     none
# 68868                   none                    n.                     none
# 68871                   none                    n.                     none
# 70227                   none                    n.                     none
# 70240                   none                    n.                     none
# 70395                   none                    n.                     none
# 71228                   none                    n.                     none
# 72270                   none                    n.                     none
# 72456                   none                    n.                     none
# 72965                   none                    n.                     none
# 73333                   none                    n.                     none
# 73854                   none                    n.                     none
# 74082                   none                    n.                     none
# 74152                   none                    n.                     none
# 74710                   none                    n.                     none
# 74848                   none                    n.                     none
#
#        ... genre_id cited corecited parent_id source_id isFT isNEW  \
# 18382  ...        4     0       0.0  34040276      none    1     0
# 25295  ...        4     0       0.0  33948873      none    1     0
# 31014  ...        4     0       0.0  34171258      none    1     0
# 32820  ...        4     0       0.0  33963364      none    1     0
# 34408  ...        4     1       0.0  34488476      none    1     0
# 46775  ...        4     0       0.0  34830439      none    1     0
# 56231  ...        4     0       0.0  37288376      none    1     1
# 57347  ...        4     9       0.0  39822952      none    1     1
# 57399  ...        4     0       0.0  41138501      none    1     1
# 58866  ...        4     0       0.0  41238907      none    0     0
# 60608  ...        4     0       0.0  39516834      none    1     0
# 61830  ...        4     0       0.0  42738747      none    0     0
# 62687  ...        4     0       0.0  44875213      none    0     1
# 63264  ...        4     0       0.0  42508954      none    0     0
# 63802  ...        4     1       0.0  42441168      none    1     1
# 64213  ...        4     0       0.0  43175461      none    0     1
# 64826  ...        4     0       0.0  42608196      none    0     0
# 65733  ...        4     0       0.0  43321669      none    0     1
# 68508  ...        4     0       0.0  44263576      none    0     1
# 68821  ...        4     0       0.0  47471628      none    0     1
# 68868  ...        4     0       0.0  42608196      none    0     0
# 68871  ...        4     0       0.0  42615041      none    0     0
# 70227  ...        4     0       0.0  44803074      none    0     1
# 70240  ...        4     0       0.0  45583743      none    0     1
# 70395  ...        4     0       0.0  46440540      none    0     1
# 71228  ...        4     0       0.0  46153772      none    0     1
# 72270  ...        4     0       0.0  44643011      none    0     1
# 72456  ...        4     0       0.0  45687883      none    0     1
# 72965  ...        4     0       0.0  43818809      none    0     1
# 73333  ...        4     0       0.0  47447400      none    0     1
# 73854  ...        4     0       0.0  46376102      17.0    0     1
# 74082  ...        4     0       0.0  34337643      17.0    0     1
# 74152  ...        4     0       0.0  47744784      none    0     1
# 74710  ...        4     0       0.0  43085908      17.0    1     1
# 74848  ...        4     0       0.0  46601009      17.0    1     1
#
#                                           link  \
# 18382  http://elibrary.ru/item.asp?id=22649492
# 25295  http://elibrary.ru/item.asp?id=21322840
# 31014  http://elibrary.ru/item.asp?id=24710185
# 32820  http://elibrary.ru/item.asp?id=21598217
# 34408  http://elibrary.ru/item.asp?id=29454634
# 46775  http://elibrary.ru/item.asp?id=32383601
# 56231  http://elibrary.ru/item.asp?id=37288426
# 57347  http://elibrary.ru/item.asp?id=39822976
# 57399  http://elibrary.ru/item.asp?id=41138509
# 58866  http://elibrary.ru/item.asp?id=41238908
# 60608  http://elibrary.ru/item.asp?id=39517318
# 61830  http://elibrary.ru/item.asp?id=42738769
# 62687  http://elibrary.ru/item.asp?id=44875224
# 63264  http://elibrary.ru/item.asp?id=42508991
# 63802  http://elibrary.ru/item.asp?id=42441176
# 64213  http://elibrary.ru/item.asp?id=43175475
# 64826  http://elibrary.ru/item.asp?id=42608206
# 65733  http://elibrary.ru/item.asp?id=43321677
# 68508  http://elibrary.ru/item.asp?id=44263588
# 68821  http://elibrary.ru/item.asp?id=47471630
# 68868  http://elibrary.ru/item.asp?id=42608209
# 68871  http://elibrary.ru/item.asp?id=42615047
# 70227  http://elibrary.ru/item.asp?id=44803080
# 70240  http://elibrary.ru/item.asp?id=45583754
# 70395  http://elibrary.ru/item.asp?id=46440551
# 71228  http://elibrary.ru/item.asp?id=46153777
# 72270  http://elibrary.ru/item.asp?id=44643023
# 72456  http://elibrary.ru/item.asp?id=45687887
# 72965  http://elibrary.ru/item.asp?id=43818817
# 73333  http://elibrary.ru/item.asp?id=47447414
# 73854  http://elibrary.ru/item.asp?id=46609070
# 74082  http://elibrary.ru/item.asp?id=27460771
# 74152  http://elibrary.ru/item.asp?id=47744791
# 74710  http://elibrary.ru/item.asp?id=43085909
# 74848  http://elibrary.ru/item.asp?id=46601010
#
#                                                      url  \
# 18382                                               none
# 25295                                               none
# 31014                                               none
# 32820                                               none
# 34408                                               none
# 46775                                               none
# 56231                                               none
# 57347       http://ras.jes.su/socis/s013216250006181-2-1
# 57399                                               none
# 58866                                               none
# 60608                                               none
# 61830                                               none
# 62687                                               none
# 63264                                               none
# 63802  http://journals.rudn.ru/sociology/article/view...
# 64213                                               none
# 64826                                               none
# 65733                                               none
# 68508                                               none
# 68821                                               none
# 68868                                               none
# 68871                                               none
# 70227                                               none
# 70240                                               none
# 70395                                               none
# 71228                                               none
# 72270                                               none
# 72456                                               none
# 72965                                               none
# 73333                                               none
# 73854  https://laplageemrevista.editorialaar.com/inde...
# 74082                                               none
# 74152                                               none
# 74710  https://www.lamjol.info/index.php/REICE/articl...
# 74848                                               none
#
#                                                      ref
# 18382  Ковтун, Н.М. ДЕСТРУКТИВНІСТЬ ЯК СКЛАДОВА СОЦІА...
# 25295  Грібер, Ю.О. КОЛЬОРОВА ДИНАМІКА МІСЬКОГО ПРОСТ...
# 31014  Скаленко, О.К. ГЛОБАЛЬНІ ВЗАЄМОЗВ’ЯЗКИ І ВСЕЗА...
# 32820  ФАУЗЕР, В.В. ВЛИЯНИЕ МИГРАЦИИ НА ЭТНОДЕМОГРАФИ...
# 34408  Hern?ndez, O. Particularidades del desarrollo ...
# 46775  Профессия"тьютор"всовременном российском социа...
# 56231  MANAGEMENT OF NATIONAL RELATIONS AS THE IMPLEM...
# 57347  Образ жизни и отношение к здоровью российских ...
# 57399  Skulmovskaya, L.G. L'influence Mutuelle Des Cu...
# 58866  Golovina, Е.V. PROBL?MES SOCIO-CULTURELS DE LA...
# 60608  Суютбекова, М. MARKETING IN BUSINESS PLANNING ...
# 61830  Klyuchnikova, Т.N. M?thodes de sociologie visu...
# 62687  Revazov, V.C. PSYCHOLOGISCHE MOTIVATION DES BE...
# 63264  Salamatina, I.I. SOCIALISATION COMME UN FACTEU...
# 63802  Проекты местного развития в Приладожье: причин...
# 64213  Medvedeva, N.I. Zum Problem des Fernstudiums a...
# 64826  Revazov, V.C. ?ber die Rolle der Frau in der g...
# 65733  Medvedeva, N.I. Au probl?me de la sant? mental...
# 68508  Kolmykova, M.A. ZUR FRAGE DES VERH?LTNISSES DE...
# 68821  Ревазов, В.Ч. ЖЕЗ?КШЕЛІК ?О?АМНЫ? ?ЛЕУМЕТТІК А...
# 68868  Demetradze, M.R. Motivation f?r das Verhalten ...
# 68871  Revazov, V.C. Soziale Aspekte der Entwicklung ...
# 70227  РАЗРЯДТАУ ??РЫЛ?ЫСЫНЫ? ?ЫЗДЫРУ ТЕМПЕРАТУРАСЫНА...
# 70240  Belyakov, A.V. CARACT?RISTIQUES DE LA FORMATIO...
# 70395  Shipulina, N.B. DIE REFLEXION VON MODE UND STI...
# 71228  Кузьмичев, Е.С. ЖАС ?РПА?ТЫ? ?АЖ ?ЫЗМЕТКЕРЛЕРІ...
# 72270  Revazov, V.C. DIE ROLLE UND DER ORT DES EMPIRI...
# 72456  Belyakov, A.V. NOTFALL - THEORIE ODER RECHTLIC...
# 72965  Katusov, D.N. Lebensmittelsicherheit / D.N. Ka...
# 73333  Plyushch, I.V. SOZIALES FREIZEITINSTITUT ALS S...
# 73854  Compensa??o por danos ambientais sob o direito...
# 74082  Czirikowa, A. Odnowa elity politycznej - studi...
# 74152  Faleev, A.N. SOURCES DE D?VELOPPEMENT SOCIAL: ...
# 74710  Zaitseva, I.A. El uso de publicidad de servici...
# 74848  Jermolajeva, P. Urheilun suurtapahtumat ja eko...
#
# [35 rows x 105 columns]

# %%
problem1 = df[df['author_1_eng last name'] == 'none'] # создаем отдельный датафрейм
problem1.to_excel('problem1.xlsx', index=None) # сохраняем проблемные строчки в отдельный датасет

# %% [markdown]
# **Во-вторых**, нами было обнаружено, что иногда в фамилиях оказываются вопросы. Нет какой-то универсальной логики по которым они там оказываются, как видно по таблице ниже, поэтому они требуют ручной обработки. Встречаемость – 0.01% в наших данных (в абсолютном значении - 11 случаев).

# %%
round(11 / df.shape[0] * 100, 2)
# Out:
# 0.01

# %%
problem2_ids = []
for j in range(df.shape[0]):
    for i in range(1, 8+1):
        author_eng_last_name = df.loc[j, f'author_{i}_eng last name']
        author_ru_last_name = df.loc[j, f'author_{i}_ru last name']
        if '?' in author_eng_last_name or '?' in author_ru_last_name:
            problem2_ids.append(df.loc[j, 'id'])

# %%
len(problem2_ids)  # всего
# Out:
# 11

# %%
problem2 = df[df['id'].isin(problem2_ids)]
problem2
# Out:
#              id  genreId author_1_id author_1_affiliation_id  \
# 4165   17775662        4    641147.0       [['820'], 'none']
# 8406   15628783        4         0.0       [['633'], 'none']
# 29850  21723566        4    368797.0      [['1025'], 'none']
# 31501  26460079        4    572584.0         [['634'], ['']]
# 32049  21723557        4         0.0      [['1025'], 'none']
# 32050  21723558        4         0.0      [['1025'], 'none']
# 32051  21723571        4         0.0      [['1025'], 'none']
# 36231  27239519        4    387234.0       [['903'], 'none']
# 61975  37418742        4         0.0      [['258'], ['258']]
# 66247  45784958        4    342670.0       [['199'], 'none']
# 69691  45788067        4    342670.0       [['199'], 'none']
#
#       author_1_ru last name author_1_ru initials  \
# 4165                П?розов                 В.А.
# 8406              Воробь?ва                 Т.Ю.
# 29850             Литвинова                 Л.В.
# 31501                  Шаов                 А.А.
# 32049               Куркина                 Е.И.
# 32050             Гаврилова                 К.В.
# 32051               Гуреева                 А.А.
# 36231              Молодов?                 О.Б.
# 61975             М?рат?ызы                   А.
# 66247             К?рчансен                   М.
# 69691             К?рчансем                   М.
#
#                                  author_1_ru affiliation  \
# 4165   ['Пермский государственный педагогический унив...
# 8406   ['Южно-Российский государственный технический ...
# 29850  ['Филиал государственного бюджетного образоват...
# 31501  ['Адыгейский государственный университет, г. М...
# 32049  ['Филиал государственного бюджетного образоват...
# 32050  ['Филиал государственного бюджетного образоват...
# 32051  ['Филиал государственного бюджетного образоват...
# 36231  ['Алтайский государственный педагогический уни...
# 61975          ['Алтайский государственный университет']
# 66247        ['Воронежский государственный университет']
# 69691        ['Воронежский государственный университет']
#
#       author_1_eng last name author_1_eng initials  \
# 4165                 P?rozov                  V.A.
# 8406               Vorob'?va                 T.JU.
# 29850              Litvinova                  L.V.
# 31501                  Shaov                  A.A.
# 32049                Kurkina                  E.I.
# 32050              Gavrilova                  K.V.
# 32051                Gureeva                  A.A.
# 36231               Molodov?                  O.B.
# 61975              M?rat?yzy                    A.
# 66247             K?rchansen                    M.
# 69691             K?rchansem                    M.
#
#                            author_1_eng affiliation  ... genre_id cited  \
# 4165                                           none  ...        4     0
# 8406                                           none  ...        4     0
# 29850                                          none  ...        4     0
# 31501  ['Adygeya State University, Maykop, Russia']  ...        4     8
# 32049                                          none  ...        4     0
# 32050                                          none  ...        4     0
# 32051                                          none  ...        4     0
# 36231                                          none  ...        4     2
# 61975                    ['Altai State University']  ...        4     0
# 66247                                          none  ...        4     0
# 69691                                          none  ...        4     0
#
#       corecited parent_id source_id isFT isNEW  \
# 4165        0.0  33737245      none    1     0
# 8406        0.0  33657214      none    1     1
# 29850       0.0  33970688      none    0     1
# 31501       0.0  34254698      none    1     0
# 32049       0.0  33970688      none    0     1
# 32050       0.0  33970688      none    0     1
# 32051       0.0  33970688      none    0     1
# 36231       0.0  34330161      none    1     1
# 61975       0.0  37418727      none    1     0
# 66247       0.0  45784951      none    1     1
# 69691       0.0  45788059      none    1     1
#
#                                           link   url  \
# 4165   http://elibrary.ru/item.asp?id=17775662  none
# 8406   http://elibrary.ru/item.asp?id=15628783  none
# 29850  http://elibrary.ru/item.asp?id=21723566  none
# 31501  http://elibrary.ru/item.asp?id=26460079  none
# 32049  http://elibrary.ru/item.asp?id=21723557  none
# 32050  http://elibrary.ru/item.asp?id=21723558  none
# 32051  http://elibrary.ru/item.asp?id=21723571  none
# 36231  http://elibrary.ru/item.asp?id=27239519  none
# 61975  http://elibrary.ru/item.asp?id=37418742  none
# 66247  http://elibrary.ru/item.asp?id=45784958  none
# 69691  http://elibrary.ru/item.asp?id=45788067  none
#
#                                                      ref
# 4165   П?розов, В.А. Образ интеллигенции российского ...
# 8406   Воробь?ва, Т.Ю. ЦВЕТОВАЯ ДИНАМИКА МОДЫ ИЛИ МОД...
# 29850  Литвинова, Л.В. НЕПРАВИЛЬНОЕ ПИТАНИЕ, КАК ИСТО...
# 31501  ШАОВ, А.А. НАЦИОНАЛЬНЫЕ ИНТЕРЕСЫ В КОНТЕКСТЕ Э...
# 32049  Куркина, Е.И. АНАЛИЗ РЕАЛИЗАЦИИ ДОЛГОСРОЧНОЙ Ц...
# 32050  Гаврилова, К.В. СОЦИАЛЬНАЯ ЗАЩИТА ДЕТЕЙ-ИНВАЛИ...
# 32051  Гуреева, А.А. СПОСОБНОСТЬ ЛИЧНОСТИ В СОВРЕМЕНН...
# 36231  Молодов?, О.Б. Предпосылки регионального сепар...
# 61975  М?рат?ызы, А. СОВРЕМЕННОЕ СОСТОЯНИЕ МИГРАЦИОНН...
# 66247  К?рчансен, М. КУЛЬТУРНЫЙ НАЦИОНАЛИЗМ В НАЦИОНА...
# 69691  К?рчансем, М. "Ч?ВАШ ХАЛ?Х ЮРРИ" И "GWLAD Y G?...
#
# [11 rows x 105 columns]

# %%
problem2.to_excel('problem2.xlsx', index=None)

# %% [markdown]
# И, в-третьих, обнаружилось что иногда в фамилиях оказываются вбиты имена (судя по отсутствующим инициалам). Это в основном случаи авторов с не русскими фамилиями ии имиенами (например, `Нгуен Тхе Зунг`, `Соларес Сиерра`), но сложно выделить единую логику по которым можно было бы определить что является инициалами, а что фамилией, поэтому нами было принято решение выгрузить такие строки отдельно и вручную пробежаться по этим авторам на сайте Elibrary. Встречаемость проблемы – 0.14% (в абсолютном значении - 108 случаев).

# %%
hard_names = []
problem3_ids = []
index = 0
for i in range(1, 8+1):
    for j in range(df.shape[0]):
        last_name = df.loc[j, f'author_{i}_ru last name']
        if len(last_name.split()) > 1 and '(' not in last_name:
            problem3_ids.append(df.loc[j, 'id'])

problem3_ids = list(set(problem3_ids))
# Решение - оценить масштаб проблемы (в публикациях)

# %%
print(len(problem3_ids))
# Out:
# 108

# %%
problem3 = df[df['id'].isin(problem3_ids)]
problem3
# Out:
#              id  genreId author_1_id       author_1_affiliation_id  \
# 12     15515293        4         0.0           [['15117'], 'none']
# 52     15563443        4         0.0           [['15117'], 'none']
# 71     15583296        4    249783.0            [['500'], ['500']]
# 169    16558268        4         0.0             [['867'], 'none']
# 268    15211711        4         0.0           [['15117'], 'none']
# ...         ...      ...         ...                           ...
# 70478  46636738        4         0.0              ['none', 'none']
# 72729  45608087        4         0.0          [['2541'], ['2541']]
# 72985  43858676        4         0.0  [['', '4812'], ['', '4812']]
# 73132  35324794        4         0.0             [['322'], 'none']
# 75113  47531770        4    730489.0                  [[''], ['']]
#
#       author_1_ru last name author_1_ru initials  \
# 12           Нгуен Тхе Зунг                 none
# 52                 Кан Ен Э                 none
# 71                Аймаутова                 Н.Е.
# 169            Лань Цзюн Ли                 Ц.Л.
# 268           Сун Гуйцзюань                 none
# ...                     ...                  ...
# 70478              фон Визе                   Л.
# 72729            Тянь Сяоюй                 none
# 72985        Соларес Сиерра                 Э.Б.
# 73132            Майга Сори                   И.
# 75113     Вальдес Одриосола                 М.С.
#
#                                  author_1_ru affiliation  \
# 12                                             ['МГУКИ']
# 52                                             ['МГУКИ']
# 71             ['Российский университет дружбы народов']
# 169                                             ['ТОГУ']
# 268                                            ['МГУКИ']
# ...                                                  ...
# 70478                                               none
# 72729  ['Московский государственный университет им. М...
# 72985  ['университет Ольгина', 'Российский государств...
# 73132                  ['Южный федеральный университет']
# 75113  ['Библиотека № 2 им. Ю. В. Трифонова ГБУК горо...
#
#       author_1_eng last name author_1_eng initials  \
# 12            Nguen the zung                  none
# 52                  Kan en e                  none
# 71                 Ajmautova                  N.E.
# 169           Lan' tszjun li                 TS.L.
# 268          Sun gujtszjuan'                  none
# ...                      ...                   ...
# 70478               Fon vize                    L.
# 72729          Tjan' sjaojuj                  none
# 72985         Solares sierra                  E.B.
# 73132             Majga sori                    I.
# 75113      Val'des odriosola                  M.S.
#
#                                 author_1_eng affiliation  ... genre_id cited  \
# 12                                                  none  ...        4     0
# 52                                                  none  ...        4     0
# 71              ['Peoples Friendship University Russia']  ...        4     0
# 169                                                 none  ...        4     2
# 268                                                 none  ...        4     0
# ...                                                  ...  ...      ...   ...
# 70478                                               none  ...        4     0
# 72729              ['Lomonosov Moscow State University']  ...        4     0
# 72985  ['University of Holgu?n', 'Russian State Socia...  ...        4     0
# 73132                                               none  ...        4     0
# 75113  ['the Library No 2 Yury Trifonov of the State ...  ...        4     0
#
#       corecited parent_id source_id isFT isNEW  \
# 12          0.0  33652048      none    1     1
# 52          0.0  33654722      none    1     1
# 71          0.0  33655525      none    1     0
# 169         0.0  33666699      none    1     0
# 268         0.0  33600246      none    1     1
# ...         ...       ...       ...  ...   ...
# 70478       0.0  46636735      none    1     1
# 72729       0.0  45608080      none    1     1
# 72985       0.0  43858673      none    1     1
# 73132       0.0  35324772      none    1     0
# 75113       0.0  47531766      none    1     1
#
#                                           link  \
# 12     http://elibrary.ru/item.asp?id=15515293
# 52     http://elibrary.ru/item.asp?id=15563443
# 71     http://elibrary.ru/item.asp?id=15583296
# 169    http://elibrary.ru/item.asp?id=16558268
# 268    http://elibrary.ru/item.asp?id=15211711
# ...                                        ...
# 70478  http://elibrary.ru/item.asp?id=46636738
# 72729  http://elibrary.ru/item.asp?id=45608087
# 72985  http://elibrary.ru/item.asp?id=43858676
# 73132  http://elibrary.ru/item.asp?id=35324794
# 75113  http://elibrary.ru/item.asp?id=47531770
#
#                                                      url  \
# 12                                                  none
# 52                                                  none
# 71                                                  none
# 169                                                 none
# 268                                                 none
# ...                                                  ...
# 70478                                               none
# 72729                                               none
# 72985  http://dom-hors.ru/rus/files/arhiv_zhurnala/sp...
# 73132                                               none
# 75113                                               none
#
#                                                      ref
# 12     Нгуен Тхе Зунг СИСТЕМА ОБСЛУЖИВАНИЯ ЧИТАТЕЛЕЙ ...
# 52     Кан Ен Э ХРИСТИАНСКАЯ ПЕВЧЕСКАЯ КУЛЬТУРА В ЛИТ...
# 71     Аймаутова, Н.Е. Социолог как продавец услуг. П...
# 169    Лань Цзюн Ли, Ц.Л. СОВРЕМЕННЫЕ ПОДХОДЫ К ИССЛЕ...
# 268    Сун Гуйцзюань ЭПОС "ГЭСЭРИАДА" И ЕГО КУЛЬТУРНЫ...
# ...                                                  ...
# 70478  фон Визе, Л. Идеациональная и чувственная куль...
# 72729  Тянь Сяоюй Особенности регулирования социальны...
# 72985  Соларес Сиерра, Э.Б. Молодые внутренние мигран...
# 73132  Майга Сори, И. Способы урегулирования межэтнич...
# 75113  Вальдес Одриосола, М.С. СОЦИОКУЛЬТУРНЫЕ АСПЕКТ...
#
# [108 rows x 105 columns]

# %%
problem3.to_excel('problem3.xlsx', index=None)

# %% [markdown]
# ## Часть 2.

# %%
# На этом этапе предполагается, что до второй части вы вручную пробежались по проблемным строкам,
# можете их загрузить и обновить вашу таблицу, чтобы вместо старых "проблемных" строк остались новые
problem1_solved = pd.read_excel('problem1_solved.xlsx')
problem2_solved = pd.read_excel('problem2_solved.xlsx')
problem3_solved = pd.read_excel('problem3_solved.xlsx')
df = pd.concat([df, problem1_solved, problem2_solved, problem3_solved])
df = df.drop_duplicates(by='id', keep='last')
